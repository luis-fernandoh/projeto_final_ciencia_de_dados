# %% [markdown]
# ## Impactos dos Problemas de Infraestrutura e Condução Imprudente nas Rodovias Federais Brasileiras
# **Nome:** Leonardo Quederoli Leme - **RA:** 241020409<br>
# **Nome:** Luís Fernando das Chagas - **RA:** 241020034

# %% [markdown]
# ## Contexto do problema

# %%
# Importação das bibliotecas necessárias
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Requirement already satisfied: matplotlib in C:\Users\leona\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.11.2)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\leona\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (1.4.0)
# Requirement already satisfied: cycler>=0.10 in C:\Users\leona\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in C:\Users\leona\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (4.65.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\leona\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (1.5.1)
# Requirement already satisfied: numpy>=1.25 in C:\Users\leona\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (2.5.3)
# Requirement already satisfied: packaging>=20.0 in C:\Users\leona\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (26.3)
# Requirement already satisfied: pillow>=9 in C:\Users\leona\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\leona\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\leona\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\leona\AppData\Local\Programs\Python\Python314\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
